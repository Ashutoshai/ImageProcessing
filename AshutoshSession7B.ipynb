# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutoshai/ImageProcessing/blob/master/AshutoshSession7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import neceesary modules

from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,SeparableConv2D,Conv2D
from keras.layers import Activation, Flatten, Dense, Dropout, Lambda, GlobalAveragePooling2D, AveragePooling2D, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils, plot_model

from keras.models import Model
from keras.layers import Input
from keras.layers.merge import concatenate,Add
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Import and load cifar10 dataset

from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
# Display randomly selected examples from each of the classes

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# Define a function to plot training and test accuracies and losses during the training

def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# define a function to calculate accuracy based on passed model, test data and test labels

def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Stadandardize the data by converting it to float32 and dividing by max pixel value 255

train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255

# convert class labels to binary class labels in one hot encoding
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# Code Explanation
#
# **------------------------------------**
#
# If we look at the ENAS generated CIFAR-10 model, we see that there are lots of skip connections. These connections are from layers appearing earlier in the model to the later layers. Number of skip connections are as high as 7 for some layers. These connections are concatenated together and fed as input to the next layer. So one major problem we will encounter is matching the shape (size and number of channels) of the channels. In order to concatenate channels they shoulb be of same size. Now convolution layers in the network have padding so that they will not reduce the channel sizes hence only maxPooling layers will reduce the channel size. So we will have larger size channels coming in to be merged with smaller size channels. We solve this issue by using 'Space to Depth algorithm.
#
# To implement the skip connections so that model design looks self explaining and uncluttered, we have defined a function adjustInputsConcat(refInput, inputList). This function takes parameter input refInput i.e. target channel with required size and inputList i.e. skip connections to be merged along with refInput. The function will apply space-to-depth algorithm on each of the inputs in the inputList to match its size with that of refInput and concat all the modified inputs with refInput and return the same.
#
# Usage:
#
# in<sub>1</sub>  --> layer1 --> out<sub>1</sub>
#
# out<sub>1</sub> --> Layer2 --> Out<sub>2</sub>
#
# out<sub>2</sub> --> Layer3 --> out<sub>3</sub>
#
# Out<sub>1</sub> + Out<sub>2</sub> + Out<sub>3</sub>--> Layer4 -->Out<sub>4</sub>
#
# In this case we can use adjustInputsConcat as
#
# adjustInputsConcat(Out<sub>3</sub>, [Out<sub>1</sub>, Out<sub>2</sub>]) --> Layer4 --> Out<sub>4</sub>
#
# The function adjustInputsConcat also append the layer prefixes
#  For Example:
#  Layers 1,2,3 and 4 are merged with 4 being the reference channel concatenate layer will be named 'Concate_L4_L3_L2_L1'.

# %%
import tensorflow as tf
# this function uses space to depth algo to match shapes of inputs in inputList with refInput (reference)
# and adjust the higher shape to lower one

def adjustInputsConcat(refInput, inputList):
  shapeAdjustedList = [refInput]
  concateLayerName = 'Concate_' + refInput.name.split('_')[0]
  for i in inputList:
    # calculate factor by which the size needs to be reduced
    s2dFactor = (i.shape[1])//(refInput.shape[1])
    # Generate the Concatenation layer name by appending the layer names being concatenated
    concateLayerName = concateLayerName + '_' + i.name.split('_')[0]
    # Apply space to depth only if the calculated factor is more than equal to 2 else append the input unchanged
    if s2dFactor >=2:
      shapeAdjustedList.append(Lambda(tf.space_to_depth, arguments={'block_size':s2dFactor},)(i))      
    else :
      shapeAdjustedList.append(i) 
      
    concatedOut = concatenate(shapeAdjustedList, name= concateLayerName)
  return concatedOut

# %%
from keras import regularizers
regLambda = 0.02

# Input layer 
inputLayer = Input(shape=(32,32,3)) #32

layer1 = SeparableConv2D(32, kernel_size = 5, padding='same', name = 'L1_Sep5x5',
                         kernel_regularizer=regularizers.l2(regLambda))(inputLayer)   #
layer1 = BatchNormalization(name = 'L1_BNORM')(layer1)
layer1 = Activation('relu', name = 'L1_Relu')(layer1)
layer1 = Dropout(0.05, name = 'L1_DrpOut')(layer1)


layer2 = Conv2D(32, kernel_size = 5, padding='same', name = 'L2_Conv5x5',
                kernel_regularizer=regularizers.l2(regLambda))(layer1)   
layer2 = BatchNormalization( name = 'L2_BNORM')(layer2)
layer2 = Activation('relu', name = 'L2_Relu')(layer2)
layer2 = Dropout(0.1, name = 'L2_DrpOut')(layer2)

layer3 = Conv2D(32, kernel_size = 5, padding='same', name = 'L3_Conv5x5',
                kernel_regularizer=regularizers.l2(regLambda))(layer2)   # 
layer3 = BatchNormalization(name = 'L3_BNORM')(layer3)
layer3 = Activation('relu',name = 'L3_Relu')(layer3)
layer3 = Dropout(0.1, name = 'L3_DrpOut')(layer3)

layer4 = SeparableConv2D(32, kernel_size = 5, padding='same', name = 'L4_Sep5x5',
                         kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer3,[layer1]))   # Skip connections from layer1
layer4 = BatchNormalization(name = 'L4_BNORM')(layer4)
layer4 = Activation('relu',name = 'L4_Relu')(layer4)
layer4 = Dropout(0.15, name = 'L4_DrpOut')(layer4)

layer5 = MaxPooling2D(pool_size=(2, 2), name = 'L5_MaxPool2x2')(adjustInputsConcat(layer4,[layer1]))           # Skip connections from layer1

layer6 = SeparableConv2D(64, kernel_size = 3, padding='same', name = 'L6_Sep3x3',
                         kernel_regularizer=regularizers.l2(regLambda))(layer5)   # 
layer6 = BatchNormalization(name = 'L6_BNORM')(layer6)
layer6 = Activation('relu',name = 'L6_Relu')(layer6)
layer6 = Dropout(0.15, name = 'L6_DrpOut')(layer6)

layer7 = Conv2D(64, kernel_size = 5, padding='same', name = 'L7_Conv5x5',                            # Skip connections from layer1, layer4
                kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer6,[layer1, layer4]))    
layer7 = BatchNormalization(name = 'L7_BNORM')(layer7)
layer7 = Activation('relu',name = 'L7_Relu')(layer7)
layer7 = Dropout(0.2, name = 'L7_DrpOut')(layer7)

layer8 = SeparableConv2D(64, kernel_size = 3, padding='same', name = 'L8_Sep3x3',                    # Skip connections from layer3, layer4, layer6
                         kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer7,[layer3, layer4, layer6])) 
layer8 = BatchNormalization(name = 'L8_BNORM')(layer8)
layer8 = Activation('relu',name = 'L8_Relu')(layer8)
layer8 = Dropout(0.2, name = 'L8_DrpOut')(layer8)

layer9 = SeparableConv2D(64, kernel_size = 5, padding='same', name = 'L9_Sep5x5',                    # Skip connections from layer1, layer3, layer4, layer 6, layer7
                         kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer8,[layer1, layer3, layer4, layer6, layer7]))    
layer9 = BatchNormalization(name = 'L9_BNORM')(layer9)
layer9 = Activation('relu',name = 'L9_Relu')(layer9)
layer9 = Dropout(0.25, name = 'L9_DrpOut')(layer9)

layer10 = MaxPooling2D(pool_size=(2, 2),name = 'L10_MaxPool2x2')(adjustInputsConcat(layer9,[layer1, layer4, layer6, layer8])) # Skip connections from layer1, layer4, layer 6, layer8

layer11 = Conv2D(128, kernel_size = 5, padding='same', name = 'L11_Conv5x5',                    # Skip connections from layer7 
                 kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer10,[layer7]))   # 
layer11 = BatchNormalization(name = 'L11_BNORM')(layer11)
layer11 = Activation('relu',name = 'L11_Relu')(layer11)
layer11 = Dropout(0.25, name = 'L11_DrpOut')(layer11)

layer12 = SeparableConv2D(128, kernel_size = 5, padding='same', name = 'L12_Sep5x5',            # Skip connections from layer2, layer4, layer8
                          kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer11,[layer2, layer4, layer8]))   # 
layer12 = BatchNormalization(name = 'L12_BNORM')(layer12)
layer12 = Activation('relu',name = 'L12_Relu')(layer12)
layer12 = Dropout(0.30, name = 'L12_DrpOut')(layer12)

layer13 = Conv2D(128, kernel_size = 3, padding='same', name = 'L13_Conv3x3',                    # Skip connections from layer2, layer3, layer6, layer11
                 kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer12,[layer2, layer3, layer6, layer11]))   # 
layer13 = BatchNormalization(name = 'L13_BNORM')(layer13)
layer13 = Activation('relu',name = 'L13_Relu')(layer13)
layer13 = Dropout(0.35, name = 'L13_DrpOut')(layer13)

layer14 = SeparableConv2D(128, kernel_size = 5, padding='same', name = 'L14_Sep5x5',            # Skip connections from layer1, layer3, layer4, layer 6, layer8, layer12
                          kernel_regularizer=regularizers.l2(regLambda))(adjustInputsConcat(layer13,[layer1, layer3, layer4, layer6, layer8, layer12]))   # 
layer14 = BatchNormalization(name = 'L14_BNORM')(layer14)
layer14 = Activation('relu', name = 'L14_Relu')(layer14)
layer14 = Dropout(0.40, name = 'L14_DrpOut')(layer14)

layer15 = GlobalAveragePooling2D()(adjustInputsConcat(layer14,[layer4, layer8, layer12]))   # Skip connections from layer4, layer8, layer12
layer16 = Dense(10)(layer15)
outputLayer = Activation('softmax')(layer16)


model = Model(inputs=inputLayer, outputs=outputLayer)
# summarize layers
print(model.summary())
# plot graph
plot_model(model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# L1_Sep5x5 (SeparableConv2D)     (None, 32, 32, 32)   203         input_1[0][0]
# __________________________________________________________________________________________________
# L1_BNORM (BatchNormalization)   (None, 32, 32, 32)   128         L1_Sep5x5[0][0]
# __________________________________________________________________________________________________
# L1_Relu (Activation)            (None, 32, 32, 32)   0           L1_BNORM[0][0]
# __________________________________________________________________________________________________
# L1_DrpOut (Dropout)             (None, 32, 32, 32)   0           L1_Relu[0][0]
# __________________________________________________________________________________________________
# L2_Conv5x5 (Conv2D)             (None, 32, 32, 32)   25632       L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# L2_BNORM (BatchNormalization)   (None, 32, 32, 32)   128         L2_Conv5x5[0][0]
# __________________________________________________________________________________________________
# L2_Relu (Activation)            (None, 32, 32, 32)   0           L2_BNORM[0][0]
# __________________________________________________________________________________________________
# L2_DrpOut (Dropout)             (None, 32, 32, 32)   0           L2_Relu[0][0]
# __________________________________________________________________________________________________
# L3_Conv5x5 (Conv2D)             (None, 32, 32, 32)   25632       L2_DrpOut[0][0]
# __________________________________________________________________________________________________
# L3_BNORM (BatchNormalization)   (None, 32, 32, 32)   128         L3_Conv5x5[0][0]
# __________________________________________________________________________________________________
# L3_Relu (Activation)            (None, 32, 32, 32)   0           L3_BNORM[0][0]
# __________________________________________________________________________________________________
# L3_DrpOut (Dropout)             (None, 32, 32, 32)   0           L3_Relu[0][0]
# __________________________________________________________________________________________________
# Concate_L3_L1 (Concatenate)     (None, 32, 32, 64)   0           L3_DrpOut[0][0]
#                                                                  L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# L4_Sep5x5 (SeparableConv2D)     (None, 32, 32, 32)   3680        Concate_L3_L1[0][0]
# __________________________________________________________________________________________________
# L4_BNORM (BatchNormalization)   (None, 32, 32, 32)   128         L4_Sep5x5[0][0]
# __________________________________________________________________________________________________
# L4_Relu (Activation)            (None, 32, 32, 32)   0           L4_BNORM[0][0]
# __________________________________________________________________________________________________
# L4_DrpOut (Dropout)             (None, 32, 32, 32)   0           L4_Relu[0][0]
# __________________________________________________________________________________________________
# Concate_L4_L1 (Concatenate)     (None, 32, 32, 64)   0           L4_DrpOut[0][0]
#                                                                  L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# L5_MaxPool2x2 (MaxPooling2D)    (None, 16, 16, 64)   0           Concate_L4_L1[0][0]
# __________________________________________________________________________________________________
# L6_Sep3x3 (SeparableConv2D)     (None, 16, 16, 64)   4736        L5_MaxPool2x2[0][0]
# __________________________________________________________________________________________________
# L6_BNORM (BatchNormalization)   (None, 16, 16, 64)   256         L6_Sep3x3[0][0]
# __________________________________________________________________________________________________
# L6_Relu (Activation)            (None, 16, 16, 64)   0           L6_BNORM[0][0]
# __________________________________________________________________________________________________
# L6_DrpOut (Dropout)             (None, 16, 16, 64)   0           L6_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 128)  0           L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 128)  0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L6_L1_L4 (Concatenate)  (None, 16, 16, 320)  0           L6_DrpOut[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# L7_Conv5x5 (Conv2D)             (None, 16, 16, 64)   512064      Concate_L6_L1_L4[0][0]
# __________________________________________________________________________________________________
# L7_BNORM (BatchNormalization)   (None, 16, 16, 64)   256         L7_Conv5x5[0][0]
# __________________________________________________________________________________________________
# L7_Relu (Activation)            (None, 16, 16, 64)   0           L7_BNORM[0][0]
# __________________________________________________________________________________________________
# L7_DrpOut (Dropout)             (None, 16, 16, 64)   0           L7_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16, 16, 128)  0           L3_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 128)  0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L7_L3_L4_L6 (Concatenat (None, 16, 16, 384)  0           L7_DrpOut[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  L6_DrpOut[0][0]
# __________________________________________________________________________________________________
# L8_Sep3x3 (SeparableConv2D)     (None, 16, 16, 64)   28096       Concate_L7_L3_L4_L6[0][0]
# __________________________________________________________________________________________________
# L8_BNORM (BatchNormalization)   (None, 16, 16, 64)   256         L8_Sep3x3[0][0]
# __________________________________________________________________________________________________
# L8_Relu (Activation)            (None, 16, 16, 64)   0           L8_BNORM[0][0]
# __________________________________________________________________________________________________
# L8_DrpOut (Dropout)             (None, 16, 16, 64)   0           L8_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 128)  0           L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 128)  0           L3_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16, 16, 128)  0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L8_L1_L3_L4_L6_L7 (Conc (None, 16, 16, 576)  0           L8_DrpOut[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  L6_DrpOut[0][0]
#                                                                  L7_DrpOut[0][0]
# __________________________________________________________________________________________________
# L9_Sep5x5 (SeparableConv2D)     (None, 16, 16, 64)   51328       Concate_L8_L1_L3_L4_L6_L7[0][0]
# __________________________________________________________________________________________________
# L9_BNORM (BatchNormalization)   (None, 16, 16, 64)   256         L9_Sep5x5[0][0]
# __________________________________________________________________________________________________
# L9_Relu (Activation)            (None, 16, 16, 64)   0           L9_BNORM[0][0]
# __________________________________________________________________________________________________
# L9_DrpOut (Dropout)             (None, 16, 16, 64)   0           L9_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 128)  0           L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16, 16, 128)  0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L9_L1_L4_L6_L8 (Concate (None, 16, 16, 448)  0           L9_DrpOut[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  L6_DrpOut[0][0]
#                                                                  L8_DrpOut[0][0]
# __________________________________________________________________________________________________
# L10_MaxPool2x2 (MaxPooling2D)   (None, 8, 8, 448)    0           Concate_L9_L1_L4_L6_L8[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 8, 8, 256)    0           L7_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L10_L7 (Concatenate)    (None, 8, 8, 704)    0           L10_MaxPool2x2[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# L11_Conv5x5 (Conv2D)            (None, 8, 8, 128)    2252928     Concate_L10_L7[0][0]
# __________________________________________________________________________________________________
# L11_BNORM (BatchNormalization)  (None, 8, 8, 128)    512         L11_Conv5x5[0][0]
# __________________________________________________________________________________________________
# L11_Relu (Activation)           (None, 8, 8, 128)    0           L11_BNORM[0][0]
# __________________________________________________________________________________________________
# L11_DrpOut (Dropout)            (None, 8, 8, 128)    0           L11_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 8, 8, 512)    0           L2_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 8, 8, 512)    0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 8, 8, 256)    0           L8_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L11_L2_L4_L8 (Concatena (None, 8, 8, 1408)   0           L11_DrpOut[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
# __________________________________________________________________________________________________
# L12_Sep5x5 (SeparableConv2D)    (None, 8, 8, 128)    215552      Concate_L11_L2_L4_L8[0][0]
# __________________________________________________________________________________________________
# L12_BNORM (BatchNormalization)  (None, 8, 8, 128)    512         L12_Sep5x5[0][0]
# __________________________________________________________________________________________________
# L12_Relu (Activation)           (None, 8, 8, 128)    0           L12_BNORM[0][0]
# __________________________________________________________________________________________________
# L12_DrpOut (Dropout)            (None, 8, 8, 128)    0           L12_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 8, 8, 512)    0           L2_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 8, 8, 512)    0           L3_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 8, 8, 256)    0           L6_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L12_L2_L3_L6_L11 (Conca (None, 8, 8, 1536)   0           L12_DrpOut[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  lambda_16[0][0]
#                                                                  L11_DrpOut[0][0]
# __________________________________________________________________________________________________
# L13_Conv3x3 (Conv2D)            (None, 8, 8, 128)    1769600     Concate_L12_L2_L3_L6_L11[0][0]
# __________________________________________________________________________________________________
# L13_BNORM (BatchNormalization)  (None, 8, 8, 128)    512         L13_Conv3x3[0][0]
# __________________________________________________________________________________________________
# L13_Relu (Activation)           (None, 8, 8, 128)    0           L13_BNORM[0][0]
# __________________________________________________________________________________________________
# L13_DrpOut (Dropout)            (None, 8, 8, 128)    0           L13_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 8, 8, 512)    0           L1_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 8, 8, 512)    0           L3_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 8, 8, 512)    0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 8, 8, 256)    0           L6_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 8, 8, 256)    0           L8_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L13_L1_L3_L4_L6_L8_L12  (None, 8, 8, 2304)   0           L13_DrpOut[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  L12_DrpOut[0][0]
# __________________________________________________________________________________________________
# L14_Sep5x5 (SeparableConv2D)    (None, 8, 8, 128)    352640      Concate_L13_L1_L3_L4_L6_L8_L12[0]
# __________________________________________________________________________________________________
# L14_BNORM (BatchNormalization)  (None, 8, 8, 128)    512         L14_Sep5x5[0][0]
# __________________________________________________________________________________________________
# L14_Relu (Activation)           (None, 8, 8, 128)    0           L14_BNORM[0][0]
# __________________________________________________________________________________________________
# L14_DrpOut (Dropout)            (None, 8, 8, 128)    0           L14_Relu[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 8, 8, 512)    0           L4_DrpOut[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 8, 8, 256)    0           L8_DrpOut[0][0]
# __________________________________________________________________________________________________
# Concate_L14_L4_L8_L12 (Concaten (None, 8, 8, 1024)   0           L14_DrpOut[0][0]
#                                                                  lambda_22[0][0]
#                                                                  lambda_23[0][0]
#                                                                  L12_DrpOut[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1024)         0           Concate_L14_L4_L8_L12[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           10250       global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           dense_1[0][0]
# ==================================================================================================
# Total params: 5,255,925
# Trainable params: 5,254,133
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Use keras ImageDataGenerator to obtain normalized training and testing data batches

from keras.preprocessing.image import ImageDataGenerator


# Initialize ImageDataGenerator for image normalization for training
datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True, zoom_range=0.0, 
                             horizontal_flip=False)

# Learn stats of training data eg. mean, std
datagen.fit(train_features)

# Define batch size
BS=128
# Generate an iterator for training. It will provide nomalized image data of size BS for training
train_iterator = datagen.flow(train_features, train_labels, batch_size = BS)

# Since we will train the model on normalized image data we must used normalized images for validation as well
# Initialize ImageDataGenerator for image normalization for testing
datagenTest = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True, zoom_range=0.0, 
                             horizontal_flip=False)

# Learn stats of testing data eg. mean, std
datagenTest.fit(test_features)


# Generate an iterator for training. It will provide nomalized image data of size BS for testing
test_iterator = datagenTest.flow(test_features, test_labels, batch_size = BS)

# %%
from google.colab import drive
from keras.callbacks import ModelCheckpoint
  
# mount google drive to save  model
drive.mount('/content/drive')


fileNameWeights = '/content/drive/My Drive/Assignment7BBest.h5'

# save model weights to 'fileNameWeights' each time the validation accuracy improves
checkpoint = ModelCheckpoint(fileNameWeights, monitor='val_acc', verbose=1, save_best_only=True,save_weights_only=True, mode='max')
callbacks_list = [checkpoint]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
start = time.time()

# Train the model
# argument 'steps_per_epoch' defines how many times train_iterator will run in batches of training data
# argument 'validation_steps' defines how many times test_iterator will run in batches of validation data
# here validation is being performed in batches instead of one shot to avoid using up too much memory while training
model_info = model.fit_generator(train_iterator, steps_per_epoch = (len(train_features)//BS), epochs = 100, 
                                 validation_data = test_iterator, validation_steps = (len(test_features)//BS),
                                 callbacks=callbacks_list, verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(model_info)
# Out:
# Epoch 1/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.8168 - acc: 0.7572 - val_loss: 1.6342 - val_acc: 0.5319
#
# Epoch 00001: val_acc improved from -inf to 0.53185, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 2/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.7701 - acc: 0.7746 - val_loss: 0.8565 - val_acc: 0.7423
#
# Epoch 00002: val_acc improved from 0.53185 to 0.74230, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 3/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.7281 - acc: 0.7890 - val_loss: 1.1296 - val_acc: 0.6545
#
# Epoch 00003: val_acc did not improve from 0.74230
# Epoch 4/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.6957 - acc: 0.7991 - val_loss: 1.1567 - val_acc: 0.6567
#
# Epoch 00004: val_acc did not improve from 0.74230
# Epoch 5/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.6668 - acc: 0.8087 - val_loss: 1.2746 - val_acc: 0.6334
#
# Epoch 00005: val_acc did not improve from 0.74230
# Epoch 6/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.6347 - acc: 0.8182 - val_loss: 1.8762 - val_acc: 0.5523
#
# Epoch 00006: val_acc did not improve from 0.74230
# Epoch 7/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.6075 - acc: 0.8266 - val_loss: 0.9838 - val_acc: 0.7216
#
# Epoch 00007: val_acc did not improve from 0.74230
# Epoch 8/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.5864 - acc: 0.8331 - val_loss: 1.1090 - val_acc: 0.6809
#
# Epoch 00008: val_acc did not improve from 0.74230
# Epoch 9/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.5616 - acc: 0.8417 - val_loss: 0.8395 - val_acc: 0.7564
#
# Epoch 00009: val_acc improved from 0.74230 to 0.75638, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 10/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.5426 - acc: 0.8469 - val_loss: 0.9762 - val_acc: 0.7238
#
# Epoch 00010: val_acc did not improve from 0.75638
# Epoch 11/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.5242 - acc: 0.8543 - val_loss: 0.7901 - val_acc: 0.7786
#
# Epoch 00011: val_acc improved from 0.75638 to 0.77857, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 12/100
# 390/390 [==============================] - 124s 319ms/step - loss: 0.5050 - acc: 0.8601 - val_loss: 1.1904 - val_acc: 0.6974
#
# Epoch 00012: val_acc did not improve from 0.77857
# Epoch 13/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.4873 - acc: 0.8646 - val_loss: 0.8758 - val_acc: 0.7608
#
# Epoch 00013: val_acc did not improve from 0.77857
# Epoch 14/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.4668 - acc: 0.8716 - val_loss: 1.2249 - val_acc: 0.6502
#
# Epoch 00014: val_acc did not improve from 0.77857
# Epoch 15/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.4546 - acc: 0.8775 - val_loss: 0.8610 - val_acc: 0.7611
#
# Epoch 00015: val_acc did not improve from 0.77857
# Epoch 16/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.4361 - acc: 0.8803 - val_loss: 0.8527 - val_acc: 0.7624
#
# Epoch 00016: val_acc did not improve from 0.77857
# Epoch 17/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.4295 - acc: 0.8847 - val_loss: 0.9683 - val_acc: 0.7357
#
# Epoch 00017: val_acc did not improve from 0.77857
# Epoch 18/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.4119 - acc: 0.8884 - val_loss: 1.0791 - val_acc: 0.7048
#
# Epoch 00018: val_acc did not improve from 0.77857
# Epoch 19/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3995 - acc: 0.8935 - val_loss: 0.8800 - val_acc: 0.7629
#
# Epoch 00019: val_acc did not improve from 0.77857
# Epoch 20/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3894 - acc: 0.8950 - val_loss: 0.7999 - val_acc: 0.7872
#
# Epoch 00020: val_acc improved from 0.77857 to 0.78718, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 21/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.3816 - acc: 0.8991 - val_loss: 0.8972 - val_acc: 0.7674
#
# Epoch 00021: val_acc did not improve from 0.78718
# Epoch 22/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3712 - acc: 0.9005 - val_loss: 0.9793 - val_acc: 0.7408
#
# Epoch 00022: val_acc did not improve from 0.78718
# Epoch 23/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3618 - acc: 0.9056 - val_loss: 0.9189 - val_acc: 0.7565
#
# Epoch 00023: val_acc did not improve from 0.78718
# Epoch 24/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.3434 - acc: 0.9098 - val_loss: 0.8674 - val_acc: 0.7681
#
# Epoch 00024: val_acc did not improve from 0.78718
# Epoch 25/100
# 390/390 [==============================] - 124s 318ms/step - loss: 0.3360 - acc: 0.9130 - val_loss: 1.1309 - val_acc: 0.7191
#
# Epoch 00025: val_acc did not improve from 0.78718
# Epoch 26/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3377 - acc: 0.9122 - val_loss: 0.8427 - val_acc: 0.7824
#
# Epoch 00026: val_acc did not improve from 0.78718
# Epoch 27/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3295 - acc: 0.9157 - val_loss: 0.9493 - val_acc: 0.7554
#
# Epoch 00027: val_acc did not improve from 0.78718
# Epoch 28/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3293 - acc: 0.9154 - val_loss: 1.0926 - val_acc: 0.7318
#
# Epoch 00028: val_acc did not improve from 0.78718
# Epoch 29/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.3119 - acc: 0.9210 - val_loss: 0.8604 - val_acc: 0.7810
#
# Epoch 00029: val_acc did not improve from 0.78718
# Epoch 30/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.3043 - acc: 0.9241 - val_loss: 1.2290 - val_acc: 0.7173
#
# Epoch 00030: val_acc did not improve from 0.78718
# Epoch 31/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.3016 - acc: 0.9241 - val_loss: 1.1343 - val_acc: 0.7406
#
# Epoch 00031: val_acc did not improve from 0.78718
# Epoch 32/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2937 - acc: 0.9280 - val_loss: 0.9307 - val_acc: 0.7764
#
# Epoch 00032: val_acc did not improve from 0.78718
# Epoch 33/100
# 390/390 [==============================] - 123s 317ms/step - loss: 0.2894 - acc: 0.9285 - val_loss: 0.9644 - val_acc: 0.7639
#
# Epoch 00033: val_acc did not improve from 0.78718
# Epoch 34/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2794 - acc: 0.9292 - val_loss: 0.7966 - val_acc: 0.7969
#
# Epoch 00034: val_acc improved from 0.78718 to 0.79690, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 35/100
# 390/390 [==============================] - 123s 317ms/step - loss: 0.2794 - acc: 0.9321 - val_loss: 1.0192 - val_acc: 0.7600
#
# Epoch 00035: val_acc did not improve from 0.79690
# Epoch 36/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2731 - acc: 0.9315 - val_loss: 0.9747 - val_acc: 0.7690
#
# Epoch 00036: val_acc did not improve from 0.79690
# Epoch 37/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2643 - acc: 0.9354 - val_loss: 0.9842 - val_acc: 0.7726
#
# Epoch 00037: val_acc did not improve from 0.79690
# Epoch 38/100
# 390/390 [==============================] - 123s 317ms/step - loss: 0.2638 - acc: 0.9363 - val_loss: 1.0941 - val_acc: 0.7419
#
# Epoch 00038: val_acc did not improve from 0.79690
# Epoch 39/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2575 - acc: 0.9363 - val_loss: 0.9680 - val_acc: 0.7711
#
# Epoch 00039: val_acc did not improve from 0.79690
# Epoch 40/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2482 - acc: 0.9382 - val_loss: 0.9634 - val_acc: 0.7749
#
# Epoch 00040: val_acc did not improve from 0.79690
# Epoch 41/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2523 - acc: 0.9383 - val_loss: 1.0386 - val_acc: 0.7601
#
# Epoch 00041: val_acc did not improve from 0.79690
# Epoch 42/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2359 - acc: 0.9419 - val_loss: 0.9863 - val_acc: 0.7613
#
# Epoch 00042: val_acc did not improve from 0.79690
# Epoch 43/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.2287 - acc: 0.9447 - val_loss: 0.9625 - val_acc: 0.7799
#
# Epoch 00043: val_acc did not improve from 0.79690
# Epoch 44/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2322 - acc: 0.9436 - val_loss: 0.8859 - val_acc: 0.7850
#
# Epoch 00044: val_acc did not improve from 0.79690
# Epoch 45/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2206 - acc: 0.9460 - val_loss: 0.8956 - val_acc: 0.7866
#
# Epoch 00045: val_acc did not improve from 0.79690
# Epoch 46/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.2270 - acc: 0.9432 - val_loss: 1.0162 - val_acc: 0.7655
#
# Epoch 00046: val_acc did not improve from 0.79690
# Epoch 47/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.2233 - acc: 0.9435 - val_loss: 0.8923 - val_acc: 0.7851
#
# Epoch 00047: val_acc did not improve from 0.79690
# Epoch 48/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2153 - acc: 0.9471 - val_loss: 1.0258 - val_acc: 0.7673
#
# Epoch 00048: val_acc did not improve from 0.79690
# Epoch 49/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2067 - acc: 0.9478 - val_loss: 1.1915 - val_acc: 0.7503
#
# Epoch 00049: val_acc did not improve from 0.79690
# Epoch 50/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2122 - acc: 0.9482 - val_loss: 0.9894 - val_acc: 0.7717
#
# Epoch 00050: val_acc did not improve from 0.79690
# Epoch 51/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2045 - acc: 0.9510 - val_loss: 0.9692 - val_acc: 0.7779
#
# Epoch 00051: val_acc did not improve from 0.79690
# Epoch 52/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2002 - acc: 0.9514 - val_loss: 1.4718 - val_acc: 0.7168
#
# Epoch 00052: val_acc did not improve from 0.79690
# Epoch 53/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.2051 - acc: 0.9501 - val_loss: 0.8503 - val_acc: 0.7992
#
# Epoch 00053: val_acc improved from 0.79690 to 0.79923, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 54/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1985 - acc: 0.9513 - val_loss: 0.9869 - val_acc: 0.7836
#
# Epoch 00054: val_acc did not improve from 0.79923
# Epoch 55/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1982 - acc: 0.9518 - val_loss: 0.8690 - val_acc: 0.8044
#
# Epoch 00055: val_acc improved from 0.79923 to 0.80440, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 56/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1960 - acc: 0.9525 - val_loss: 0.9495 - val_acc: 0.7921
#
# Epoch 00056: val_acc did not improve from 0.80440
# Epoch 57/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1842 - acc: 0.9566 - val_loss: 0.9727 - val_acc: 0.7756
#
# Epoch 00057: val_acc did not improve from 0.80440
# Epoch 58/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1962 - acc: 0.9521 - val_loss: 0.9545 - val_acc: 0.7751
#
# Epoch 00058: val_acc did not improve from 0.80440
# Epoch 59/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1848 - acc: 0.9564 - val_loss: 0.8357 - val_acc: 0.8090
#
# Epoch 00059: val_acc improved from 0.80440 to 0.80895, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 60/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1800 - acc: 0.9561 - val_loss: 0.9527 - val_acc: 0.7946
#
# Epoch 00060: val_acc did not improve from 0.80895
# Epoch 61/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1815 - acc: 0.9558 - val_loss: 1.0461 - val_acc: 0.7743
#
# Epoch 00061: val_acc did not improve from 0.80895
# Epoch 62/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1724 - acc: 0.9579 - val_loss: 1.0079 - val_acc: 0.7704
#
# Epoch 00062: val_acc did not improve from 0.80895
# Epoch 63/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1805 - acc: 0.9568 - val_loss: 1.1449 - val_acc: 0.7625
#
# Epoch 00063: val_acc did not improve from 0.80895
# Epoch 64/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1718 - acc: 0.9572 - val_loss: 0.9618 - val_acc: 0.7916
#
# Epoch 00064: val_acc did not improve from 0.80895
# Epoch 65/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1705 - acc: 0.9583 - val_loss: 0.9899 - val_acc: 0.7795
#
# Epoch 00065: val_acc did not improve from 0.80895
# Epoch 66/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1687 - acc: 0.9589 - val_loss: 1.2683 - val_acc: 0.7510
#
# Epoch 00066: val_acc did not improve from 0.80895
# Epoch 67/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1654 - acc: 0.9603 - val_loss: 1.1112 - val_acc: 0.7613
#
# Epoch 00067: val_acc did not improve from 0.80895
# Epoch 68/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1658 - acc: 0.9595 - val_loss: 1.0575 - val_acc: 0.7756
#
# Epoch 00068: val_acc did not improve from 0.80895
# Epoch 69/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1590 - acc: 0.9631 - val_loss: 1.1076 - val_acc: 0.7474
#
# Epoch 00069: val_acc did not improve from 0.80895
# Epoch 70/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1634 - acc: 0.9611 - val_loss: 0.9089 - val_acc: 0.7971
#
# Epoch 00070: val_acc did not improve from 0.80895
# Epoch 71/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1607 - acc: 0.9626 - val_loss: 0.9917 - val_acc: 0.7758
#
# Epoch 00071: val_acc did not improve from 0.80895
# Epoch 72/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1610 - acc: 0.9619 - val_loss: 1.0360 - val_acc: 0.7675
#
# Epoch 00072: val_acc did not improve from 0.80895
# Epoch 73/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1523 - acc: 0.9632 - val_loss: 1.0558 - val_acc: 0.7740
#
# Epoch 00073: val_acc did not improve from 0.80895
# Epoch 74/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1516 - acc: 0.9651 - val_loss: 0.8185 - val_acc: 0.8103
#
# Epoch 00074: val_acc improved from 0.80895 to 0.81027, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 75/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1568 - acc: 0.9638 - val_loss: 0.8573 - val_acc: 0.8011
#
# Epoch 00075: val_acc did not improve from 0.81027
# Epoch 76/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1541 - acc: 0.9642 - val_loss: 1.0614 - val_acc: 0.7855
#
# Epoch 00076: val_acc did not improve from 0.81027
# Epoch 77/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1565 - acc: 0.9628 - val_loss: 0.9942 - val_acc: 0.7902
#
# Epoch 00077: val_acc did not improve from 0.81027
# Epoch 78/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1520 - acc: 0.9644 - val_loss: 1.0850 - val_acc: 0.7792
#
# Epoch 00078: val_acc did not improve from 0.81027
# Epoch 79/100
# 390/390 [==============================] - 123s 317ms/step - loss: 0.1496 - acc: 0.9643 - val_loss: 0.9343 - val_acc: 0.7932
#
# Epoch 00079: val_acc did not improve from 0.81027
# Epoch 80/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1486 - acc: 0.9651 - val_loss: 0.9295 - val_acc: 0.8034
#
# Epoch 00080: val_acc did not improve from 0.81027
# Epoch 81/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1449 - acc: 0.9660 - val_loss: 1.0558 - val_acc: 0.7845
#
# Epoch 00081: val_acc did not improve from 0.81027
# Epoch 82/100
# 390/390 [==============================] - 123s 317ms/step - loss: 0.1403 - acc: 0.9677 - val_loss: 0.9892 - val_acc: 0.7837
#
# Epoch 00082: val_acc did not improve from 0.81027
# Epoch 83/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1401 - acc: 0.9664 - val_loss: 0.9171 - val_acc: 0.7949
#
# Epoch 00083: val_acc did not improve from 0.81027
# Epoch 84/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1415 - acc: 0.9668 - val_loss: 1.3363 - val_acc: 0.7484
#
# Epoch 00084: val_acc did not improve from 0.81027
# Epoch 85/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1445 - acc: 0.9659 - val_loss: 1.0426 - val_acc: 0.7799
#
# Epoch 00085: val_acc did not improve from 0.81027
# Epoch 86/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1435 - acc: 0.9669 - val_loss: 0.9296 - val_acc: 0.7989
#
# Epoch 00086: val_acc did not improve from 0.81027
# Epoch 87/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1408 - acc: 0.9671 - val_loss: 0.9053 - val_acc: 0.8047
#
# Epoch 00087: val_acc did not improve from 0.81027
# Epoch 88/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1361 - acc: 0.9692 - val_loss: 1.0016 - val_acc: 0.7934
#
# Epoch 00088: val_acc did not improve from 0.81027
# Epoch 89/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1371 - acc: 0.9680 - val_loss: 0.8431 - val_acc: 0.8095
#
# Epoch 00089: val_acc did not improve from 0.81027
# Epoch 90/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1362 - acc: 0.9684 - val_loss: 0.9125 - val_acc: 0.8020
#
# Epoch 00090: val_acc did not improve from 0.81027
# Epoch 91/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1376 - acc: 0.9666 - val_loss: 0.9151 - val_acc: 0.7983
#
# Epoch 00091: val_acc did not improve from 0.81027
# Epoch 92/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1294 - acc: 0.9689 - val_loss: 0.9682 - val_acc: 0.7918
#
# Epoch 00092: val_acc did not improve from 0.81027
# Epoch 93/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1291 - acc: 0.9698 - val_loss: 0.9774 - val_acc: 0.7904
#
# Epoch 00093: val_acc did not improve from 0.81027
# Epoch 94/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1330 - acc: 0.9692 - val_loss: 0.9990 - val_acc: 0.7849
#
# Epoch 00094: val_acc did not improve from 0.81027
# Epoch 95/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1302 - acc: 0.9709 - val_loss: 1.1960 - val_acc: 0.7649
#
# Epoch 00095: val_acc did not improve from 0.81027
# Epoch 96/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1296 - acc: 0.9703 - val_loss: 0.8857 - val_acc: 0.8029
#
# Epoch 00096: val_acc did not improve from 0.81027
# Epoch 97/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1343 - acc: 0.9687 - val_loss: 0.8484 - val_acc: 0.8152
#
# Epoch 00097: val_acc improved from 0.81027 to 0.81524, saving model to /content/drive/My Drive/Assignment7BBest.h5
# Epoch 98/100
# 390/390 [==============================] - 123s 315ms/step - loss: 0.1327 - acc: 0.9695 - val_loss: 1.2554 - val_acc: 0.7498
#
# Epoch 00098: val_acc did not improve from 0.81524
# Epoch 99/100
# 390/390 [==============================] - 124s 317ms/step - loss: 0.1246 - acc: 0.9727 - val_loss: 0.9322 - val_acc: 0.8031
#
# Epoch 00099: val_acc did not improve from 0.81524
# Epoch 100/100
# 390/390 [==============================] - 123s 316ms/step - loss: 0.1280 - acc: 0.9716 - val_loss: 1.3612 - val_acc: 0.7538
#
# Epoch 00100: val_acc did not improve from 0.81524
# Model took 12345.50 seconds to train

# %%
# Load Best saved model weights
model.load_weights(fileNameWeights, by_name=True)

# Since we have trained our model on Normalized input images hence normalizing the test data before predicting test accuracy
test_iterator = datagenTest.flow(test_features, test_labels, batch_size = test_features.shape[0])

# Obtain a batch a normalized test data
batchX, batchY = test_iterator.next()

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(batchX, batchY, model))
# Out:
# Accuracy on test data is: 81.40
